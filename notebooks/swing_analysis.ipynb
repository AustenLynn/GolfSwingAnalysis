# %% [markdown]
# # Swing Analysis
# Notebook for exploring captured and processed swing datasets.

# %%
import pandas as pd
from pathlib import Path

raw_dir = Path('../data/raw')
processed_dir = Path('../data/processed')
print('Raw files:', [p.name for p in raw_dir.glob('*.csv')])
print('Processed files:', [p.name for p in processed_dir.glob('*.csv')])
